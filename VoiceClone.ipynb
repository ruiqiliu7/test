# %% [markdown]
# Step 1: Setup and Imports

# %%
# Step 1: Setup and Imports
import os
import librosa
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import logging
import soundfile as sf
import noisereduce as nr
from scipy.signal import butter, lfilter

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# Step 2: Audio Preprocessing

# %%
# Step 2: Audio Preprocessing
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    return b, a

def bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

def preprocess_audio(audio_path, output_path):
    y, sr = librosa.load(audio_path, sr=None)
    y_reduced = nr.reduce_noise(y=y, sr=sr, prop_decrease=0.9)
    y_equalized = bandpass_filter(y_reduced, lowcut=50, highcut=8000, fs=sr, order=6)
    y_normalized = librosa.util.normalize(y_equalized)
    sf.write(output_path, y_normalized, sr)
    print(f"Processed and saved: {output_path}")

# Directory paths
input_dir = "D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/recordings"
output_dir = "D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Preprocess all audio files
for filename in os.listdir(input_dir):
    if filename.endswith(".wav"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        preprocess_audio(input_path, output_path)
# Out:
# C:\Users\10195\AppData\Local\Temp\ipykernel_17664\719272189.py:15: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)
# d:\NEU\NUwork\Voice Cloning Web Application Project\myenv\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_All_work_and_no_play_makes_Jack_a_dull_boy..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_A_big_black_bear_sat_on_a_big_black_rug..wav
# C:\Users\10195\AppData\Local\Temp\ipykernel_17664\719272189.py:15: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)
# d:\NEU\NUwork\Voice Cloning Web Application Project\myenv\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Bright_vases_are_kept_on_the_wooden_shelf..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Choose_a_sentence_to_record.wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Current_Sentence_to_Record.wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_How_are_you_today.wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_How_much_wood_would_a_woodchuck_chuck_if_a_woodchuck_could_chuck_wood_.wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Peter_Piper_picked_a_peck_of_pickled_peppers..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Recording_saved_successfully_.wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Record_sentence_in_english.wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Record_Voice_for_test.wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_She_exercises_every_morning..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_She_sells_seashells_by_the_seashore..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_The_early_bird_catches_the_worm..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_The_quick_brown_fox_jumps_over_the_lazy_dog..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_The_rain_in_Spain_stays_mainly_in_the_plain..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_This_is_a_custom_sentence.wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_This_is_a_test..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_To_be_or_not_to_be__that_is_the_question..wav
# Processed and saved: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_We_always_eat_dinner_together..wav

# %% [markdown]
# Step 3: Data Augmentation and Feature Extraction

# %%
# Step 3: Data Augmentation and Feature Extraction
def augment_audio(y, sr):
    noise = np.random.randn(len(y))
    y_noise = y + 0.005 * noise
    y_shift = np.roll(y, sr // 10)
    y_pitch = librosa.effects.pitch_shift(y, sr=sr, n_steps=2.0)
    return [y, y_noise, y_shift, y_pitch]

def extract_features(audio_paths, sr=22050, n_mels=128, max_len=500):
    mel_specs = []
    for audio_path in audio_paths:
        y, sr = librosa.load(audio_path, sr=sr)
        logger.info(f"Audio loaded: {audio_path}, sample rate: {sr}, length: {len(y)}")
        augmented_audios = augment_audio(y, sr)
        for i, y_aug in enumerate(augmented_audios):
            mel_spec = librosa.feature.melspectrogram(y=y_aug, sr=sr, n_mels=n_mels)
            mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
            mel_spec_db = (mel_spec_db - np.mean(mel_spec_db)) / np.std(mel_spec_db)
            if mel_spec_db.shape[1] > max_len:
                mel_spec_db = mel_spec_db[:, :max_len]
            else:
                pad_width = max_len - mel_spec_db.shape[1]
                mel_spec_db = np.pad(mel_spec_db, ((0, 0), (0, pad_width)), mode='constant', constant_values=(0,))
            mel_specs.append(mel_spec_db)
    mel_specs = np.array(mel_specs)
    mel_specs = mel_specs.reshape((len(audio_paths), 4, n_mels, max_len))
    return mel_specs, mel_specs  # Dummy return for both X and y

# Load preprocessed audio files and extract features
audio_folder = "D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings"
audio_paths = [os.path.join(audio_folder, f) for f in os.listdir(audio_folder) if f.endswith('.wav')]
X_train, y_train = extract_features(audio_paths)

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_All_work_and_no_play_makes_Jack_a_dull_boy..wav, sample rate: 22050, length: 123039
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_A_big_black_bear_sat_on_a_big_black_rug..wav, sample rate: 22050, length: 150822
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Bright_vases_are_kept_on_the_wooden_shelf..wav, sample rate: 22050, length: 124362
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Choose_a_sentence_to_record.wav, sample rate: 22050, length: 101871
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Current_Sentence_to_Record.wav, sample rate: 22050, length: 97902
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_How_are_you_today.wav, sample rate: 22050, length: 79380
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_How_much_wood_would_a_woodchuck_chuck_if_a_woodchuck_could_chuck_wood_.wav, sample rate: 22050, length: 193158
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Peter_Piper_picked_a_peck_of_pickled_peppers..wav, sample rate: 22050, length: 121716
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Recording_saved_successfully_.wav, sample rate: 22050, length: 79380
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Record_sentence_in_english.wav, sample rate: 22050, length: 80703
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_Record_Voice_for_test.wav, sample rate: 22050, length: 76734
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_She_exercises_every_morning..wav, sample rate: 22050, length: 92610
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_She_sells_seashells_by_the_seashore..wav, sample rate: 22050, length: 112455
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_The_early_bird_catches_the_worm..wav, sample rate: 22050, length: 120393
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_The_quick_brown_fox_jumps_over_the_lazy_dog..wav, sample rate: 22050, length: 148176
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_The_rain_in_Spain_stays_mainly_in_the_plain..wav, sample rate: 22050, length: 123039
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_This_is_a_custom_sentence.wav, sample rate: 22050, length: 84672
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_This_is_a_test..wav, sample rate: 22050, length: 76734
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_To_be_or_not_to_be__that_is_the_question..wav, sample rate: 22050, length: 129654
# INFO:__main__:Audio loaded: D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/preprocessed_recordings\test_We_always_eat_dinner_together..wav, sample rate: 22050, length: 85995
# X_train shape: (20, 4, 128, 500)
# y_train shape: (20, 4, 128, 500)

# %% [markdown]
# Step 4: Model Training

# %%
# Step 4: Model Training
def train_tts_model(X_train, y_train):
    input_shape = (X_train.shape[2], X_train.shape[3], 1)
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        layers.Dropout(0.5),
        layers.Dense(y_train.shape[-1] * y_train.shape[-2], activation='linear'),
        layers.Reshape((y_train.shape[-2], y_train.shape[-1]))
    ])

    initial_learning_rate = 0.001
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate,
        decay_steps=100000,
        decay_rate=0.96,
        staircase=True
    )
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint('best_model.keras', save_best_only=True)
    ]

    history = model.fit(
        X_train.reshape((-1, *input_shape)),
        y_train.reshape((-1, *input_shape)),
        validation_split=0.2,
        epochs=100,
        batch_size=32,
        callbacks=callbacks
    )
    return model

model_path = "D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/models/test_tts_model.keras"
model = train_tts_model(X_train, y_train)
model.save(model_path)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 14s/step - loss: 11.5582 - val_loss: 4.9843
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 13s/step - loss: 4.5344 - val_loss: 2.8532
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 2.9337 - val_loss: 3.1971
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 3.3368 - val_loss: 3.4983
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 3.5029 - val_loss: 3.0799
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 8s/step - loss: 3.0104 - val_loss: 2.3287
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 9s/step - loss: 2.2599 - val_loss: 1.7101
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 17s/step - loss: 1.6898 - val_loss: 1.4117
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 8s/step - loss: 1.4296 - val_loss: 1.3268
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 8s/step - loss: 1.3585 - val_loss: 1.2933
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 9s/step - loss: 1.3106 - val_loss: 1.1848
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 8s/step - loss: 1.1657 - val_loss: 1.0214
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 7s/step - loss: 1.0162 - val_loss: 0.8603
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 8s/step - loss: 0.8523 - val_loss: 0.7394
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 7s/step - loss: 0.7428 - val_loss: 0.6797
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 8s/step - loss: 0.6658 - val_loss: 0.6471
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 9s/step - loss: 0.6245 - val_loss: 0.6121
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 8s/step - loss: 0.5749 - val_loss: 0.5585
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 8s/step - loss: 0.5136 - val_loss: 0.5054
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 7s/step - loss: 0.4486 - val_loss: 0.4740
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 7s/step - loss: 0.4132 - val_loss: 0.4572
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 8s/step - loss: 0.3923 - val_loss: 0.4521
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 15s/step - loss: 0.3827 - val_loss: 0.4492
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 10s/step - loss: 0.3818 - val_loss: 0.4378
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 8s/step - loss: 0.3581 - val_loss: 0.4175
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.3277 - val_loss: 0.4121
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.3182 - val_loss: 0.4039
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.3018 - val_loss: 0.3969
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2906 - val_loss: 0.3826
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2755 - val_loss: 0.3742
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2684 - val_loss: 0.3715
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2576 - val_loss: 0.3652
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2556 - val_loss: 0.3565
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2347 - val_loss: 0.3564
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2388 - val_loss: 0.3526
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.2231 - val_loss: 0.3566
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2384 - val_loss: 0.3488
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2350 - val_loss: 0.3479
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2243 - val_loss: 0.3477
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2189 - val_loss: 0.3440
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.2237 - val_loss: 0.3446
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2182 - val_loss: 0.3430
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.2214 - val_loss: 0.3512
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.2127 - val_loss: 0.3442
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.2085 - val_loss: 0.3373
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1989 - val_loss: 0.3356
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.2024 - val_loss: 0.3369
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1990 - val_loss: 0.3324
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1997 - val_loss: 0.3288
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1989 - val_loss: 0.3271
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1840 - val_loss: 0.3247
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1882 - val_loss: 0.3220
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1840 - val_loss: 0.3247
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1846 - val_loss: 0.3260
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1803 - val_loss: 0.3234
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1841 - val_loss: 0.3254
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1882 - val_loss: 0.3233
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1807 - val_loss: 0.3215
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 0.1803 - val_loss: 0.3231
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1739 - val_loss: 0.3224
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1725 - val_loss: 0.3206
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1723 - val_loss: 0.3287
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1721 - val_loss: 0.3219
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1719 - val_loss: 0.3260
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1798 - val_loss: 0.3153
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1656 - val_loss: 0.3182
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1673 - val_loss: 0.3144
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1718 - val_loss: 0.3152
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1670 - val_loss: 0.3184
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1648 - val_loss: 0.3155
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1651 - val_loss: 0.3144
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1622 - val_loss: 0.3122
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1689 - val_loss: 0.3227
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1547 - val_loss: 0.3181
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1666 - val_loss: 0.3137
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1607 - val_loss: 0.3117
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1660 - val_loss: 0.3104
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1640 - val_loss: 0.3106
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1623 - val_loss: 0.3129
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1618 - val_loss: 0.3146
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1637 - val_loss: 0.3156
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1618 - val_loss: 0.3153
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1604 - val_loss: 0.3153
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1655 - val_loss: 0.3122
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1531 - val_loss: 0.3134
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1615 - val_loss: 0.3170
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1601 - val_loss: 0.3127
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1549 - val_loss: 0.3144
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1652 - val_loss: 0.3162
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1696 - val_loss: 0.3174
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1549 - val_loss: 0.3172
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1546 - val_loss: 0.3117
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1596 - val_loss: 0.3168
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1568 - val_loss: 0.3150
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1675 - val_loss: 0.3230
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1554 - val_loss: 0.3140
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 5s/step - loss: 0.1591 - val_loss: 0.3098
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1570 - val_loss: 0.3180
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.1490 - val_loss: 0.3128
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - loss: 0.1536 - val_loss: 0.3093

# %% [markdown]
# Step 5: Model Loading and Audio Synthesis

# %%
# Step 5: Model Loading and Audio Synthesis with Audio Playback
from IPython.display import Audio, display

def load_tts_model(model_path):
    if os.path.exists(model_path):
        model = load_model(model_path)
        return model
    else:
        raise FileNotFoundError(f"Model not found at {model_path}")

def text_to_sequence(text, max_len=500, n_mels=128):
    sequence = [ord(char) for char in text]
    if len(sequence) > max_len:
        sequence = sequence[:max_len]
    else:
        sequence = sequence + [0] * (max_len - len(sequence))
    sequence = np.array(sequence)
    sequence = sequence.reshape((1, max_len))
    sequence_3d = np.zeros((1, n_mels, max_len))
    sequence_3d[0, 0, :] = sequence
    return sequence_3d

def griffin_lim(mel_spec, n_iter=100):
    stft_matrix = librosa.feature.inverse.mel_to_stft(mel_spec)
    stft_matrix = stft_matrix.astype(np.complex64)
    waveform = librosa.griffinlim(stft_matrix, n_iter=n_iter, hop_length=512)
    return waveform

def generate_audio(text, model_path):
    model = load_tts_model(model_path)
    sequence = text_to_sequence(text)
    mel_spec = model.predict(sequence)
    audio = griffin_lim(mel_spec[0])
    return audio

text = "Hello, this is a test."
result_path = "D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/synthesized/test_synthesized_audio.wav"
audio = generate_audio(text, model_path)
sf.write(result_path, audio, 22050)
print(f"Generated audio saved to {result_path}")

# Display audio player
display(Audio(audio, rate=22050))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Generated audio saved to D:/NEU/NUwork/Voice Cloning Web Application Project/VoiceCloner/media/synthesized/test_synthesized_audio.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
